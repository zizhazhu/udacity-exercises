# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
## Your code here
from collections import Counter
import random

words_n = Counter(int_words)
threshold = 1e-5
all_words = len(int_words)
frequency_words = {word: words_n[word] / all_words for word in words_n}
prob_words = {word: 1 - np.sqrt(threshold / frequency_words[word]) for word in frequency_words}
train_words = [word for word in int_words if random.random() < (1 - prob_words[word])]

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    # Your code here
    R = np.random.randint(1, window_size+1)
    first = idx - R if idx - R > 0 else 0
    end = idx + R if idx + R < len(words) else len(words) - 1
    words_set = set(words[first:idx] + words[idx+1:end+1])
    return list(words_set)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name='inputs')
    labels = tf.placeholder(tf.int32, [None, None], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding = 300
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1))
    embed = tf.nn.embedding_lookup(embedding, inputs)

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1))
    softmax_b = tf.Variable(tf.zeros(n_vocab))
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, labels, embed, n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.7789 0.0659 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.7654 0.0569 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.6118 0.0566 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.7490 0.0566 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.6367 0.0562 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.6625 0.0564 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.6414 0.0569 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.6471 0.0560 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.5424 0.0561 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.5129 0.0562 sec/batch
# Nearest to time: blaming, educated, centauri, passing, bju, railway, dogwood, adjunct,
# Nearest to by: xor, hamath, grange, xilinx, arlington, nigerians, caddy, heuss,
# Nearest to in: randomness, broomstick, cowes, nights, moulded, ingrained, every, healthcare,
# Nearest to called: boastful, bolo, montane, regionalism, bathing, vetting, sepia, notable,
# Nearest to were: portfolio, empted, monmouthshire, fca, vegetable, shilton, hegel, tenet,
# Nearest to if: borden, paisiello, hydroplane, ethnicities, excels, eurofighter, formal, conclusively,
# Nearest to also: rickover, bhikkhu, unreadable, faults, seiy, lombardi, coldcut, shen,
# Nearest to who: nancy, torrey, harnack, koichi, dien, upgrade, farkas, multiverses,
# Nearest to smith: reviewing, biography, wtro, against, phosphide, dongell, show, anne,
# Nearest to alternative: playboys, similes, perversity, clarkson, charted, nasrid, synapsids, interplanetary,
# Nearest to instance: grrm, ashley, nwa, won, lichtenfeld, unlucky, vf, coli,
# Nearest to recorded: highwaymen, eliminating, rou, listened, subgenius, polyethylene, gown, kirundi,
# Nearest to experience: albury, maximize, forcing, orgy, airbus, privateers, inhibitory, diomedea,
# Nearest to rise: dimitris, occupies, awash, theropod, pinto, oclc, reduction, order,
# Nearest to dr: rampart, harsh, overture, morum, conant, formed, dragsters, aforementioned,
# Nearest to cost: hiker, soga, szabo, maxims, phage, sacrificing, ks, donatello,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.5451 0.0576 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.4454 0.0563 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.4037 0.0562 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2933 0.0563 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.2420 0.0563 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.2163 0.0563 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.1861 0.0560 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.1085 0.0562 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 5.0841 0.0567 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 5.0482 0.0562 sec/batch
# Nearest to time: educated, passing, blaming, determine, railway, had, correctly, centauri,
# Nearest to by: xor, special, grange, hamath, heuss, xilinx, caddy, arlington,
# Nearest to in: randomness, nights, every, twenty, broomstick, healthcare, constrained, moulded,
# Nearest to called: every, boastful, bolo, notable, montane, bathing, showed, featuring,
# Nearest to were: necessarily, portfolio, vegetable, tenet, shilton, willing, slightly, interact,
# Nearest to if: including, borden, ethnicities, hydroplane, formal, conclusively, upper, requires,
# Nearest to also: unreadable, faults, rickover, necessary, bhikkhu, allow, havilland, coldcut,
# Nearest to who: nancy, torrey, koichi, upgrade, full, open, influence, loss,
# Nearest to smith: reviewing, biography, against, show, anne, wtro, attracting, caused,
# Nearest to alternative: charted, perversity, filled, steppe, playboys, bongo, similes, clarkson,
# Nearest to instance: won, unlucky, fawn, grrm, regarding, especially, coli, zwei,
# Nearest to recorded: eliminating, highwaymen, rou, listened, purchase, euthanized, subgenius, schechter,
# Nearest to experience: forcing, privateers, maximize, orgy, albury, dissertation, o, options,
# Nearest to rise: occupies, dimitris, order, reduction, analogous, focus, pinto, stiff,
# Nearest to dr: rampart, formed, harsh, despite, dominatrices, applied, morum, aforementioned,
# Nearest to cost: sacrificing, hiker, maxims, phage, soga, ks, kingu, beauty,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9760 0.0577 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.9452 0.0558 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.9408 0.0564 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.9384 0.0564 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8648 0.0562 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8935 0.0564 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.8357 0.0562 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.8462 0.0560 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.8483 0.0561 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.8517 0.0562 sec/batch
# Nearest to time: educated, blaming, passing, centauri, typography, correctly, railway, determine,
# Nearest to by: xor, grange, special, hamath, arlington, xilinx, fs, shine,
# Nearest to in: randomness, twenty, constrained, session, healthcare, mormon, ingrained, nights,
# Nearest to called: bolo, boastful, every, notable, montane, bathing, regionalism, showed,
# Nearest to were: vegetable, devil, hegel, tenet, announces, portfolio, necessarily, shilton,
# Nearest to if: ethnicities, requires, borden, conclusively, eurofighter, hydroplane, couper, atb,
# Nearest to also: rickover, unreadable, bhikkhu, faults, necessary, allow, coldcut, monterrey,
# Nearest to who: nancy, torrey, koichi, dash, wonderful, loss, upgrade, industry,
# Nearest to smith: reviewing, biography, wtro, against, show, anne, province, lending,
# Nearest to alternative: perversity, charted, bongo, filled, steppe, discussing, playboys, clarkson,
# Nearest to instance: grrm, ashley, vf, regarding, won, unlucky, pact, especially,
# Nearest to recorded: eliminating, highwaymen, listened, rou, gown, euthanized, schechter, chromosome,
# Nearest to experience: forcing, maximize, privateers, orgy, dissertation, albury, licenses, yen,
# Nearest to rise: occupies, dimitris, reduction, analogous, order, ascent, stiff, advent,
# Nearest to dr: rampart, harsh, overture, formed, aforementioned, conant, morum, dominatrices,
# Nearest to cost: hiker, sacrificing, maxims, beauty, phage, soga, ks, criteria,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.8194 0.0574 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.8085 0.0565 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7638 0.0562 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7674 0.0560 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7874 0.0563 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.7434 0.0563 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.7470 0.0564 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7925 0.0562 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.7452 0.0561 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.7187 0.0560 sec/batch
# Nearest to time: educated, blaming, passing, adjunct, centauri, ho, pretender, typography,
# Nearest to by: xor, hamath, grange, special, arlington, xilinx, fs, hardship,
# Nearest to in: randomness, twenty, broomstick, constrained, healthcare, mormon, ingrained, nights,
# Nearest to called: bolo, boastful, every, montane, bathing, notable, regionalism, obscene,
# Nearest to were: devil, announces, portfolio, tenet, hegel, vegetable, empted, ridicule,
# Nearest to if: requires, ethnicities, borden, vivid, excels, commonly, atb, eurofighter,
# Nearest to also: rickover, unreadable, faults, bhikkhu, seiy, coldcut, algeria, fractal,
# Nearest to who: nancy, torrey, loss, koichi, dash, mohammad, harnack, odos,
# Nearest to smith: biography, reviewing, wtro, show, lending, anne, eloquence, soleil,
# Nearest to alternative: interplanetary, perversity, playboys, similes, nasrid, taxpayers, charted, bongo,
# Nearest to instance: grrm, skilful, oromo, ashley, especially, regarding, vf, unlucky,
# Nearest to recorded: eliminating, highwaymen, rou, gown, listened, schechter, subgenius, chromosome,
# Nearest to experience: forcing, maximize, privateers, orgy, albury, airbus, inhibitory, lehi,
# Nearest to rise: occupies, dimitris, reduction, awash, ascent, honorably, advent, analogous,
# Nearest to dr: rampart, harsh, overture, aforementioned, conant, morum, formed, despite,
# Nearest to cost: maxims, phage, sacrificing, hiker, soga, ks, beauty, inmate,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6895 0.0572 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6763 0.0559 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6517 0.0563 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6697 0.0561 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6509 0.0576 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6955 0.0562 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.5898 0.0431 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5587 0.0566 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5206 0.0563 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.5160 0.0562 sec/batch
# Nearest to time: educated, blaming, passing, adjunct, had, centauri, ho, castello,
# Nearest to by: hamath, grange, xor, special, xilinx, nigerians, therapist, fs,
# Nearest to in: randomness, twenty, mormon, constrained, toward, broomstick, nights, session,
# Nearest to called: boastful, bolo, every, bathing, montane, notable, regionalism, obscene,
# Nearest to were: portfolio, devil, tenet, volunteered, announces, vegetable, monmouthshire, willing,
# Nearest to if: requires, ethnicities, integers, facile, excels, commonly, couper, atb,
# Nearest to also: rickover, unreadable, bhikkhu, seiy, coldcut, faults, necessary, optimise,
# Nearest to who: nancy, torrey, harnack, odos, loss, multiverses, koichi, mohammad,
# Nearest to smith: biography, reviewing, anne, wtro, eloquence, show, narnia, arbuckle,
# Nearest to alternative: similes, interplanetary, playboys, perversity, synapsids, discussing, bongo, forum,
# Nearest to instance: grrm, skilful, acoustics, especially, oromo, regarding, ashley, dimitris,
# Nearest to recorded: highwaymen, eliminating, gown, rou, listened, schechter, wielded, chromosome,
# Nearest to experience: forcing, maximize, albury, privateers, airbus, orgy, inhibitory, rammed,
# Nearest to rise: occupies, dimitris, reduction, awash, spier, ascent, stiff, honorably,
# Nearest to dr: rampart, conant, overture, morum, vipers, harsh, sworn, aforementioned,
# Nearest to cost: maxims, phage, sacrificing, soga, hiker, ks, constrained, parliamentarism,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.4610 0.0573 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.4952 0.0560 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4475 0.0562 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5205 0.0567 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.4751 0.0560 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4815 0.0561 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4365 0.0562 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.3595 0.0562 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4159 0.0562 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4084 0.0560 sec/batch
# Nearest to time: passing, had, educated, blaming, adjunct, lamorna, model, ho,
# Nearest to by: xor, hamath, grange, xilinx, special, colloquialism, nigerians, fs,
# Nearest to in: randomness, twenty, constrained, computability, toward, nights, broomstick, neophyte,
# Nearest to called: boastful, every, bolo, montane, bathing, notable, stockings, mineralogist,
# Nearest to were: devil, portfolio, volunteered, monmouthshire, vegetable, empted, willing, breasted,
# Nearest to if: we, requires, integers, couper, excels, ethnicities, mg, facile,
# Nearest to also: rickover, unreadable, bhikkhu, necessary, faults, seiy, coldcut, monterrey,
# Nearest to who: nancy, torrey, loss, odos, multiverses, harnack, mohammad, permission,
# Nearest to smith: biography, reviewing, anne, show, wtro, narnia, eloquence, arbuckle,
# Nearest to alternative: playboys, similes, interplanetary, synapsids, forum, perversity, discussing, nasrid,
# Nearest to instance: grrm, skilful, define, problems, oromo, value, acoustics, unlucky,
# Nearest to recorded: gown, eliminating, highwaymen, rou, listened, schechter, wielded, welle,
# Nearest to experience: forcing, maximize, albury, inhibitory, airbus, privateers, onside, hebert,
# Nearest to rise: occupies, reduction, dimitris, awash, advent, spier, stiff, honorably,
# Nearest to dr: rampart, overture, conant, morum, eller, sworn, garp, vipers,
# Nearest to cost: maxims, phage, sacrificing, soga, ks, constrained, assemblers, parliamentarism,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4126 0.0574 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.3899 0.0561 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4272 0.0562 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.3761 0.0560 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.4065 0.0560 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4224 0.0575 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3372 0.0558 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3552 0.0554 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4415 0.0556 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3455 0.0561 sec/batch
# Nearest to time: passing, had, blaming, lamorna, correctly, adjunct, centauri, castello,
# Nearest to by: xor, xilinx, special, grange, hamath, colloquialism, caddy, nigerians,
# Nearest to in: randomness, twenty, constrained, cowes, toward, neophyte, computability, valentine,
# Nearest to called: boastful, every, bolo, montane, obscene, bathing, notable, regionalism,
# Nearest to were: devil, vegetable, portfolio, monmouthshire, karaite, breasted, volunteered, pox,
# Nearest to if: we, couper, integers, requires, modifiers, borden, mg, ethnicities,
# Nearest to also: rickover, unreadable, bhikkhu, seiy, peleliu, faults, coldcut, monterrey,
# Nearest to who: nancy, torrey, odos, permission, harnack, dien, raging, elizabeth,
# Nearest to smith: biography, reviewing, anne, narnia, show, macneill, soleil, wtro,
# Nearest to alternative: interplanetary, playboys, similes, forum, perversity, synapsids, nasrid, pip,
# Nearest to instance: grrm, skilful, especially, coli, heterosexual, regarding, nx, problems,
# Nearest to recorded: gown, eliminating, listened, highwaymen, rou, wielded, schechter, ulema,
# Nearest to experience: forcing, albury, inhibitory, rammed, maximize, airbus, orgy, onside,
# Nearest to rise: occupies, dimitris, reduction, awash, spier, oclc, advent, reactant,
# Nearest to dr: rampart, overture, conant, sworn, morum, dizzy, aforementioned, eller,
# Nearest to cost: phage, maxims, sacrificing, soga, assemblers, hiker, parliamentarism, constrained,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3698 0.0571 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.3813 0.0561 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3298 0.0561 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3642 0.0560 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.3636 0.0562 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.4040 0.0562 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3969 0.0555 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3825 0.0555 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.2976 0.0557 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3333 0.0553 sec/batch
# Nearest to time: had, passing, blaming, castello, correctly, lamorna, reactivated, educated,
# Nearest to by: xor, hamath, special, grange, arlington, signet, therapist, xilinx,
# Nearest to in: randomness, constrained, seahawks, twenty, toward, cowes, the, healthcare,
# Nearest to called: boastful, bolo, every, montane, notable, obscene, bathing, regionalism,
# Nearest to were: breasted, portfolio, devil, monmouthshire, resettle, empted, vegetable, karaite,
# Nearest to if: integers, we, modifiers, couper, requires, undercroft, restriction, multiplied,
# Nearest to also: rickover, unreadable, bhikkhu, faults, seiy, peleliu, necessary, algeria,
# Nearest to who: nancy, torrey, odos, raging, harnack, mohammad, permission, himself,
# Nearest to smith: biography, reviewing, anne, narnia, macneill, eloquence, wtro, soleil,
# Nearest to alternative: interplanetary, playboys, forum, similes, synapsids, perversity, filled, nasrid,
# Nearest to instance: grrm, skilful, especially, coli, regarding, yoshida, heterosexual, dnow,
# Nearest to recorded: gown, listened, eliminating, highwaymen, rou, schechter, wielded, ulema,
# Nearest to experience: forcing, albury, rammed, inhibitory, maximize, airbus, orgy, onside,
# Nearest to rise: occupies, dimitris, reduction, awash, oclc, spier, quantities, venting,
# Nearest to dr: rampart, overture, aforementioned, conant, dizzy, sworn, garp, morum,
# Nearest to cost: soga, maxims, assemblers, phage, sacrificing, parliamentarism, hiker, inmate,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3330 0.0567 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.3129 0.0557 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3680 0.0558 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3695 0.0562 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3867 0.0560 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2724 0.0561 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.2794 0.0559 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3140 0.0571 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.1969 0.0561 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.2982 0.0562 sec/batch
# Nearest to time: passing, had, blaming, lamorna, castello, reactivated, plasticity, workman,
# Nearest to by: xor, special, hamath, therapist, arlington, signet, grange, colloquialism,
# Nearest to in: randomness, first, twenty, constrained, cowes, the, neophyte, toward,
# Nearest to called: boastful, every, bolo, obscene, montane, notable, feasts, bathing,
# Nearest to were: portfolio, devil, breasted, empted, monmouthshire, attract, volunteered, resettle,
# Nearest to if: integers, we, couper, modifiers, requires, mg, multiplied, undercroft,
# Nearest to also: rickover, unreadable, bhikkhu, seiy, faults, coldcut, algeria, myasthenic,
# Nearest to who: nancy, torrey, odos, multiverses, permission, mohammad, harnack, dien,
# Nearest to smith: biography, reviewing, anne, macneill, narnia, wtro, arbuckle, soleil,
# Nearest to alternative: synapsids, playboys, interplanetary, forum, similes, taxpayers, filled, pip,
# Nearest to instance: grrm, skilful, especially, coli, regarding, dnow, heterosexual, nx,
# Nearest to recorded: gown, listened, highwaymen, eliminating, rou, buffalo, nac, ulema,
# Nearest to experience: forcing, albury, rammed, inhibitory, airbus, orgy, seaver, inherit,
# Nearest to rise: occupies, dimitris, reduction, awash, quantities, oclc, spier, limburg,
# Nearest to dr: rampart, overture, conant, sworn, eller, garp, aforementioned, classicists,
# Nearest to cost: soga, sacrificing, assemblers, maxims, phage, inmate, parliamentarism, constrained,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.2772 0.0572 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.3049 0.0560 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3308 0.0295 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2109 0.0561 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2153 0.0562 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.1670 0.0563 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.1917 0.0562 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.1768 0.0576 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.1695 0.0556 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1441 0.0565 sec/batch
# Nearest to time: had, passing, reactivated, blaming, castello, lamorna, plasticity, correctly,
# Nearest to by: hamath, xor, arlington, special, grange, signet, wabash, therapist,
# Nearest to in: first, twenty, the, constrained, randomness, cowes, wildfire, valentine,
# Nearest to called: feasts, bolo, boastful, every, bathing, notable, montane, obscene,
# Nearest to were: resettle, devil, pox, attract, monmouthshire, empted, portfolio, breasted,
# Nearest to if: integers, couper, modifiers, we, multiplied, undercroft, requires, maneuverability,
# Nearest to also: unreadable, rickover, bhikkhu, seiy, faults, peleliu, algeria, monterrey,
# Nearest to who: nancy, torrey, multiverses, odos, permission, wonderful, thee, mohammad,
# Nearest to smith: biography, reviewing, narnia, anne, macneill, wtro, dongell, arbuckle,
# Nearest to alternative: forum, playboys, synapsids, interplanetary, similes, taxpayers, perversity, introductory,
# Nearest to instance: grrm, especially, skilful, coli, heterosexual, regarding, dnow, ipl,
# Nearest to recorded: listened, gown, highwaymen, eliminating, buffalo, rou, nac, discography,
# Nearest to experience: forcing, inhibitory, albury, rammed, airbus, wiser, subconscious, neurological,
# Nearest to rise: occupies, dimitris, reduction, oclc, spier, quantities, awash, stiff,
# Nearest to dr: rampart, overture, conant, eller, garp, sworn, classicists, dizzy,
# Nearest to cost: soga, assemblers, sacrificing, phage, inmate, maxims, constrained, priced,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2019 0.0573 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.1775 0.0557 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.1976 0.0559 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1205 0.0554 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1501 0.0555 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1194 0.0553 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1189 0.0552 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1642 0.0554 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.1915 0.0560 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1316 0.0552 sec/batch
# Nearest to time: had, passing, lamorna, reactivated, blaming, plasticity, correctly, determine,
# Nearest to by: xor, special, arlington, signet, hamath, grange, colloquialism, therapist,
# Nearest to in: first, the, twenty, constrained, randomness, valentine, cowes, ounce,
# Nearest to called: bolo, every, montane, feasts, notable, boastful, bathing, obscene,
# Nearest to were: devil, resettle, attract, portfolio, monmouthshire, nahua, pox, breasted,
# Nearest to if: integers, couper, we, modifiers, undercroft, requires, determines, dismissed,
# Nearest to also: rickover, unreadable, bhikkhu, seiy, faults, myasthenic, dharmas, peleliu,
# Nearest to who: nancy, torrey, multiverses, odos, permission, wonderful, dien, synagogue,
# Nearest to smith: biography, reviewing, narnia, macneill, dongell, soleil, wtro, anne,
# Nearest to alternative: playboys, forum, synapsids, interplanetary, similes, pollutant, taxpayers, steppe,
# Nearest to instance: grrm, skilful, especially, dnow, heterosexual, define, coli, regarding,
# Nearest to recorded: listened, gown, highwaymen, buffalo, eliminating, nac, discography, airliners,
# Nearest to experience: forcing, inhibitory, subconscious, rammed, albury, wiser, airbus, neurological,
# Nearest to rise: dimitris, occupies, reduction, quantities, oclc, reactant, stiff, spier,
# Nearest to dr: rampart, overture, eller, conant, sworn, dizzy, garp, shania,
# Nearest to cost: soga, assemblers, phage, inmate, comoving, maxims, sacrificing, priced,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1236 0.0564 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.1853 0.0554 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1526 0.0555 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1382 0.0553 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1642 0.0553 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1439 0.0554 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.1601 0.0555 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1298 0.0554 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1128 0.0556 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1303 0.0555 sec/batch
# Nearest to time: had, passing, lamorna, reactivated, correctly, blaming, plasticity, determine,
# Nearest to by: hamath, special, arlington, xor, signet, grange, preregular, opportune,
# Nearest to in: the, first, constrained, twenty, cowes, randomness, valentine, computability,
# Nearest to called: bolo, every, bathing, obscene, boastful, feasts, montane, tittle,
# Nearest to were: resettle, monmouthshire, nahua, devil, breasted, portfolio, pox, fca,
# Nearest to if: integers, we, maneuverability, requires, undercroft, dismissed, modifiers, begging,
# Nearest to also: rickover, bhikkhu, seiy, unreadable, myasthenic, peleliu, coldcut, faults,
# Nearest to who: nancy, torrey, multiverses, odos, synagogue, wonderful, duopoly, permission,
# Nearest to smith: biography, reviewing, macneill, narnia, soleil, wtro, dongell, eloquence,
# Nearest to alternative: synapsids, interplanetary, playboys, forum, similes, pollutant, taxpayers, steppe,
# Nearest to instance: grrm, especially, skilful, dnow, heterosexual, define, regarding, nx,
# Nearest to recorded: listened, gown, highwaymen, nac, eliminating, discography, buffalo, habitat,
# Nearest to experience: forcing, subconscious, rammed, neurological, albury, inhibitory, wiser, orgy,
# Nearest to rise: dimitris, reduction, occupies, quantities, stiff, reactant, oclc, chrismation,
# Nearest to dr: rampart, overture, conant, eller, dizzy, shania, sworn, garp,
# Nearest to cost: soga, sacrificing, assemblers, inmate, maxims, earnings, constrained, parliamentarism,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.1962 0.0565 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1491 0.0555 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1458 0.0554 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1536 0.0554 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1029 0.0554 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1196 0.0553 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1466 0.0554 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.0983 0.0557 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.1946 0.0556 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.1948 0.0557 sec/batch
# Nearest to time: had, passing, lamorna, blaming, reactivated, educated, correctly, galilei,
# Nearest to by: hamath, of, arlington, grange, signet, special, therapist, dataran,
# Nearest to in: the, first, twenty, constrained, valentine, seahawks, maynard, peasant,
# Nearest to called: obscene, bolo, feasts, boastful, bathing, every, tittle, chadian,
# Nearest to were: resettle, monmouthshire, pox, devil, portfolio, attract, breasted, nahua,
# Nearest to if: integers, we, undercroft, couper, restriction, maneuverability, requires, dismissed,
# Nearest to also: rickover, bhikkhu, myasthenic, seiy, peleliu, algeria, ectocervix, faults,
# Nearest to who: nancy, odos, torrey, maude, multiverses, mohammad, duopoly, wonderful,
# Nearest to smith: biography, macneill, reviewing, narnia, soleil, dongell, wtro, eloquence,
# Nearest to alternative: synapsids, playboys, forum, interplanetary, taxpayers, similes, pollutant, xc,
# Nearest to instance: grrm, especially, skilful, dnow, heterosexual, yoshida, plaintiff, regarding,
# Nearest to recorded: highwaymen, listened, gown, eliminating, buffalo, nac, tum, discography,
# Nearest to experience: forcing, rammed, albury, subconscious, airbus, wiser, neurological, airplane,
# Nearest to rise: dimitris, reduction, occupies, quantities, oclc, limburg, reactant, stiff,
# Nearest to dr: rampart, overture, conant, eller, dizzy, garp, prof, sworn,
# Nearest to cost: soga, assemblers, sacrificing, inmate, maxims, comoving, priced, parliamentarism,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2005 0.0572 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1175 0.0555 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1233 0.0551 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1038 0.0553 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0301 0.0555 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1207 0.0555 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.0981 0.0555 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1241 0.0556 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1644 0.0159 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.0637 0.0554 sec/batch
# Nearest to time: had, passing, reactivated, lamorna, costing, adjunct, blaming, galilei,
# Nearest to by: hamath, grange, signet, wabash, arlington, therapist, special, dataran,
# Nearest to in: the, first, constrained, twenty, ol, neophyte, seahawks, and,
# Nearest to called: bolo, feasts, boastful, every, montane, dv, casaubon, chadian,
# Nearest to were: pox, devil, resettle, attract, monmouthshire, portfolio, breasted, fca,
# Nearest to if: we, integers, multiplied, excels, undercroft, facile, atb, maneuverability,
# Nearest to also: bhikkhu, rickover, seiy, myasthenic, unreadable, algeria, faults, peleliu,
# Nearest to who: nancy, maude, multiverses, torrey, duopoly, odos, wonderful, mohammad,
# Nearest to smith: biography, macneill, reviewing, narnia, dongell, soleil, wtro, eloquence,
# Nearest to alternative: synapsids, taxpayers, xc, interplanetary, playboys, pollutant, forum, similes,
# Nearest to instance: grrm, especially, skilful, dnow, regarding, heterosexual, yoshida, coloane,
# Nearest to recorded: highwaymen, listened, eliminating, gown, discography, nac, buffalo, habitat,
# Nearest to experience: forcing, subconscious, albury, rammed, airbus, wiser, inhibitory, neurological,
# Nearest to rise: occupies, dimitris, quantities, reduction, limburg, rich, reactant, stiff,
# Nearest to dr: rampart, conant, overture, sworn, prof, affecting, panavia, cruithne,
# Nearest to cost: soga, assemblers, comoving, inmate, revenue, sacrificing, maxims, priced,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0313 0.0568 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0587 0.0558 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0517 0.0557 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0283 0.0557 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0463 0.0556 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 3.9912 0.0554 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.0549 0.0554 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.0501 0.0554 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1132 0.0555 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 3.9301 0.0555 sec/batch
# Nearest to time: had, reactivated, passing, correctly, costing, lamorna, transposition, plasticity,
# Nearest to by: hamath, of, signet, wabash, therapist, grange, special, arlington,
# Nearest to in: the, first, twenty, and, seahawks, athenians, constrained, valentine,
# Nearest to called: bolo, feasts, every, chadian, hexagonal, boastful, montane, bathing,
# Nearest to were: devil, resettle, pox, attract, vegetable, nahua, mainframe, fca,
# Nearest to if: we, excels, integers, requires, facile, modifiers, undercroft, maneuverability,
# Nearest to also: bhikkhu, rickover, algeria, myasthenic, the, unreadable, seiy, monterrey,
# Nearest to who: nancy, multiverses, odos, maude, servant, duopoly, torrey, sheeana,
# Nearest to smith: macneill, biography, reviewing, narnia, dongell, wtro, soleil, byline,
# Nearest to alternative: synapsids, playboys, taxpayers, pollutant, interplanetary, forum, similes, xc,
# Nearest to instance: grrm, especially, dnow, skilful, heterosexual, regarding, yoshida, verbatim,
# Nearest to recorded: highwaymen, eliminating, listened, buffalo, discography, nac, habitat, airliners,
# Nearest to experience: forcing, subconscious, neurological, wiser, airbus, rammed, albury, inhibitory,
# Nearest to rise: occupies, dimitris, quantities, reduction, rich, limburg, swath, stiff,
# Nearest to dr: rampart, conant, overture, affecting, prof, cruithne, sworn, shania,
# Nearest to cost: soga, sacrificing, priced, teutoburg, comoving, assemblers, hiroshima, inmate,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 3.9875 0.0565 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0052 0.0560 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 3.9793 0.0553 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0293 0.0554 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0314 0.0555 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0204 0.0555 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0233 0.0554 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.0813 0.0554 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0330 0.0555 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0364 0.0554 sec/batch
# Nearest to time: had, passing, reactivated, correctly, lamorna, determine, blaming, transposition,
# Nearest to by: of, signet, xor, hamath, the, special, above, which,
# Nearest to in: the, first, seahawks, and, a, twenty, valentine, constrained,
# Nearest to called: feasts, every, bolo, dv, casaubon, boastful, obscene, tittle,
# Nearest to were: vegetable, devil, attract, pox, karaite, mainframe, resettle, cottages,
# Nearest to if: we, integers, multiplied, requires, dismissed, undercroft, y, begging,
# Nearest to also: bhikkhu, myasthenic, seiy, rickover, unreadable, faults, ectocervix, unlike,
# Nearest to who: nancy, maude, multiverses, torrey, odos, sheeana, servant, duopoly,
# Nearest to smith: macneill, reviewing, biography, wtro, dongell, narnia, scrutinized, soleil,
# Nearest to alternative: interplanetary, synapsids, pollutant, playboys, taxpayers, xc, filled, similes,
# Nearest to instance: grrm, especially, skilful, dnow, regarding, heterosexual, coloane, expository,
# Nearest to recorded: highwaymen, eliminating, discography, habitat, airliners, listened, buffalo, nac,
# Nearest to experience: forcing, subconscious, neurological, rammed, airbus, inhibitory, wiser, albury,
# Nearest to rise: dimitris, reduction, quantities, occupies, reactant, rich, oclc, stiff,
# Nearest to dr: overture, conant, rampart, prof, dizzy, shania, physiological, sworn,
# Nearest to cost: soga, sacrificing, constrained, comoving, priced, costs, maxims, assemblers,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0114 0.0566 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0443 0.0555 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0551 0.0555 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0092 0.0554 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0166 0.0556 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0272 0.0554 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0413 0.0554 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0410 0.0557 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0810 0.0554 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0364 0.0555 sec/batch
# Nearest to time: had, reactivated, passing, correctly, blaming, lamorna, galilei, costing,
# Nearest to by: the, of, hamath, and, which, signet, parastatal, wabash,
# Nearest to in: the, first, and, of, to, seahawks, a, constrained,
# Nearest to called: feasts, bolo, every, boastful, obscene, casaubon, golden, bathing,
# Nearest to were: pox, resettle, vegetable, attract, devil, was, which, karaite,
# Nearest to if: we, integers, facile, undercroft, multiplied, dismissed, begging, requires,
# Nearest to also: bhikkhu, myasthenic, mortification, rickover, seiy, peleliu, arnold, sars,
# Nearest to who: nancy, multiverses, sheeana, maude, servant, odos, duopoly, wonderful,
# Nearest to smith: macneill, reviewing, wtro, biography, dongell, narnia, scrutinized, soleil,
# Nearest to alternative: interplanetary, synapsids, pollutant, playboys, filled, taxpayers, nasrid, xc,
# Nearest to instance: grrm, especially, skilful, heterosexual, expository, regarding, plaintiff, yoshida,
# Nearest to recorded: highwaymen, eliminating, discography, buffalo, listened, nac, airliners, habitat,
# Nearest to experience: subconscious, forcing, rammed, albury, airbus, neurological, airplane, inhibitory,
# Nearest to rise: dimitris, reduction, occupies, quantities, rich, oclc, stiff, reactant,
# Nearest to dr: rampart, overture, prof, dizzy, conant, affecting, shania, bourget,
# Nearest to cost: constrained, sacrificing, soga, teutoburg, inmate, maxims, priced, taggers,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0250 0.0565 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 4.0057 0.0553 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0379 0.0554 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0587 0.0560 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0612 0.0558 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.0950 0.0555 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.0690 0.0554 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 3.9965 0.0556 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 3.9571 0.0555 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0274 0.0554 sec/batch
# Nearest to time: had, reactivated, costing, passing, lamorna, correctly, adjunct, transposition,
# Nearest to by: the, of, and, signet, wabash, parastatal, above, hamath,
# Nearest to in: the, first, and, a, seahawks, of, to, ounce,
# Nearest to called: feasts, casaubon, every, bolo, tx, tittle, dv, boastful,
# Nearest to were: pox, resettle, attract, devil, mainframe, hfr, cottages, karaite,
# Nearest to if: we, multiplied, excels, facile, requires, integers, does, vdash,
# Nearest to also: bhikkhu, rickover, seiy, azazel, myasthenic, mortification, algeria, henrik,
# Nearest to who: nancy, maude, sheeana, duopoly, multiverses, ecologists, odos, timepieces,
# Nearest to smith: macneill, dongell, reviewing, scrutinized, wtro, biography, narnia, byline,
# Nearest to alternative: interplanetary, pollutant, filled, taxpayers, synapsids, playboys, nasrid, methods,
# Nearest to instance: grrm, especially, skilful, heterosexual, expository, regarding, plaintiff, ipl,
# Nearest to recorded: highwaymen, discography, eliminating, listened, nac, buffalo, habitat, gown,
# Nearest to experience: subconscious, forcing, albury, airbus, rammed, airplane, neurological, wiser,
# Nearest to rise: dimitris, occupies, rich, reduction, limburg, agrarian, quantities, stiff,
# Nearest to dr: prof, rampart, overture, conant, bourget, sworn, cruithne, affecting,
# Nearest to cost: maxims, teutoburg, soga, sacrificing, constrained, costs, revenue, earnings,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9245 0.0568 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0096 0.0557 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0286 0.0559 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0143 0.0572 sec/batch
# Epoch 5/10 Iteration: 18500 Avg. Training loss: 4.0466 0.0025 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 3.9894 0.0575 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 3.9813 0.0564 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9584 0.0556 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0126 0.0558 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9341 0.0554 sec/batch
# Nearest to time: had, reactivated, costing, correctly, passing, lamorna, adjunct, based,
# Nearest to by: the, of, and, hamath, signet, which, wabash, above,
# Nearest to in: the, first, and, a, of, athenians, to, twenty,
# Nearest to called: feasts, casaubon, chadian, golden, dv, every, tittle, jaundice,
# Nearest to were: was, pox, devil, resettle, karaite, vegetable, been, which,
# Nearest to if: dismissed, excels, begging, facile, confess, undercroft, multiplied, we,
# Nearest to also: myasthenic, bhikkhu, rickover, ectocervix, seiy, mortification, ohio, azazel,
# Nearest to who: nancy, maude, sheeana, multiverses, wondrous, duopoly, wearing, timepieces,
# Nearest to smith: macneill, dongell, reviewing, tardis, biography, scrutinized, wtro, byline,
# Nearest to alternative: interplanetary, pollutant, filled, taxpayers, synapsids, methods, playboys, nasrid,
# Nearest to instance: grrm, especially, skilful, heterosexual, expository, plaintiff, regarding, coli,
# Nearest to recorded: highwaymen, discography, eliminating, listened, habitat, nac, mehemet, buffalo,
# Nearest to experience: albury, subconscious, airbus, forcing, airplane, rammed, neurological, inhibitory,
# Nearest to rise: dimitris, occupies, rich, reduction, stiff, spier, reactant, quantities,
# Nearest to dr: prof, rampart, sworn, cruithne, overture, affecting, conant, panavia,
# Nearest to cost: constrained, sacrificing, taggers, soga, teutoburg, menaced, maxims, earnings,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 3.9362 0.0570 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9205 0.0561 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 3.9804 0.0590 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 3.9695 0.0713 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 3.9947 0.0587 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 3.9392 0.0572 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.8774 0.0553 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9339 0.0572 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.8850 0.0620 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9494 0.0624 sec/batch
# Nearest to time: reactivated, had, costing, correctly, lamorna, cabell, passing, transposition,
# Nearest to by: the, and, of, above, which, special, signet, hamath,
# Nearest to in: the, and, first, a, of, to, seahawks, ounce,
# Nearest to called: feasts, every, terms, dv, a, rasterization, casaubon, chadian,
# Nearest to were: was, pox, devil, resettle, hfr, vegetable, attract, karaite,
# Nearest to if: we, begging, excels, requires, dismissed, multiplied, undercroft, defaults,
# Nearest to also: the, bhikkhu, myasthenic, unlike, ectocervix, rickover, mortification, ohio,
# Nearest to who: maude, nancy, wearing, sheeana, duopoly, torrey, multiverses, wondrous,
# Nearest to smith: macneill, dongell, narnia, scrutinized, tardis, biography, reviewing, wtro,
# Nearest to alternative: interplanetary, pollutant, filled, synapsids, playboys, taxpayers, nasrid, methods,
# Nearest to instance: grrm, especially, heterosexual, skilful, expository, plaintiff, regarding, frequentists,
# Nearest to recorded: highwaymen, discography, buffalo, eliminating, midnight, habitat, listened, omitting,
# Nearest to experience: subconscious, forcing, airbus, neurological, albury, airplane, rammed, inhibitory,
# Nearest to rise: dimitris, occupies, spier, reactant, reduction, rich, quantities, stiff,
# Nearest to dr: cruithne, prof, rampart, overture, shania, panavia, conant, affecting,
# Nearest to cost: sacrificing, constrained, teutoburg, menaced, taggers, iis, costs, soga,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 3.9504 0.0712 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 3.9752 0.0612 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9104 0.0752 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 3.9739 0.0564 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 3.9879 0.0564 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9458 0.0736 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 3.9522 0.0572 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 3.9775 0.0553 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 3.9638 0.0554 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 3.9800 0.0550 sec/batch
# Nearest to time: reactivated, had, costing, cabell, correctly, passing, transposition, lamorna,
# Nearest to by: the, of, and, which, signet, special, above, caddy,
# Nearest to in: the, and, first, a, seahawks, of, to, valentine,
# Nearest to called: feasts, casaubon, every, golden, cortex, rasterization, boastful, tx,
# Nearest to were: pox, was, devil, hfr, resettle, vegetable, pinball, karaite,
# Nearest to if: defaults, undercroft, dismissed, begging, atb, borden, have, multiplied,
# Nearest to also: bhikkhu, myasthenic, the, rickover, seiy, mortification, unlike, ectocervix,
# Nearest to who: maude, sheeana, nancy, wearing, torrey, timepieces, multiverses, swann,
# Nearest to smith: dongell, macneill, scrutinized, biography, reviewing, tardis, wtro, narnia,
# Nearest to alternative: interplanetary, filled, taxpayers, pollutant, playboys, synapsids, methods, nasrid,
# Nearest to instance: grrm, especially, heterosexual, skilful, expository, plaintiff, regarding, ipl,
# Nearest to recorded: highwaymen, discography, buffalo, eliminating, listened, omitting, nac, midnight,
# Nearest to experience: forcing, subconscious, neurological, albury, airbus, airplane, rammed, inhibitory,
# Nearest to rise: dimitris, reduction, reactant, spier, rich, quantities, stiff, agrarian,
# Nearest to dr: sworn, rampart, sextet, cruithne, prof, conant, panavia, overture,
# Nearest to cost: constrained, sacrificing, maxims, earnings, outperform, soga, taggers, ukiyo,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 4.0200 0.0564 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9112 0.0553 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9554 0.0552 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 3.9591 0.0676 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 3.9757 0.0775 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 3.9830 0.0608 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9443 0.0566 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9065 0.0574 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9359 0.0559 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.0161 0.0559 sec/batch
# Nearest to time: reactivated, had, costing, correctly, cabell, lamorna, passing, constantinopolitan,
# Nearest to by: the, of, and, parastatal, which, special, in, above,
# Nearest to in: the, and, of, a, first, to, seahawks, twenty,
# Nearest to called: feasts, golden, chadian, casaubon, bolo, every, terms, preorder,
# Nearest to were: was, been, pox, resettle, devil, vegetable, hfr, attract,
# Nearest to if: defaults, dismissed, does, we, undercroft, logically, restriction, integers,
# Nearest to also: the, myasthenic, ectocervix, rickover, bhikkhu, unlike, henrik, azazel,
# Nearest to who: maude, sheeana, wearing, timepieces, nancy, reservations, odos, servant,
# Nearest to smith: dongell, macneill, scrutinized, wtro, tardis, reviewing, biography, quick,
# Nearest to alternative: interplanetary, filled, pollutant, taxpayers, nasrid, synapsids, methods, playboys,
# Nearest to instance: grrm, heterosexual, especially, regarding, skilful, expository, plaintiff, coli,
# Nearest to recorded: highwaymen, discography, eliminating, habitat, buffalo, omitting, listened, mehemet,
# Nearest to experience: forcing, subconscious, albury, airplane, airbus, neurological, rammed, dissertation,
# Nearest to rise: dimitris, reactant, reduction, rich, quantities, occupies, agrarian, spier,
# Nearest to dr: cruithne, prof, rampart, sworn, sextet, conant, bourget, panavia,
# Nearest to cost: constrained, earnings, outperform, taggers, sacrificing, costs, maxims, teutoburg,
# Epoch 5/10 Iteration: 22100 Avg. Training loss: 3.9534 0.0570 sec/batch
# Epoch 5/10 Iteration: 22200 Avg. Training loss: 4.0280 0.0593 sec/batch
# Epoch 5/10 Iteration: 22300 Avg. Training loss: 4.0026 0.0680 sec/batch
# ...
# Epoch 9/10 Iteration: 38700 Avg. Training loss: 3.8075 0.0561 sec/batch
# Epoch 9/10 Iteration: 38800 Avg. Training loss: 3.7949 0.0554 sec/batch
# Epoch 9/10 Iteration: 38900 Avg. Training loss: 3.8696 0.0555 sec/batch
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 3.8644 0.0559 sec/batch
# Nearest to time: had, reactivated, moment, costing, upon, constantinopolitan, cabell, based,
# Nearest to by: the, and, of, a, in, which, as, is,
# Nearest to in: the, and, a, of, first, with, as, also,
# Nearest to called: a, an, is, late, of, as, the, for,
# Nearest to were: had, was, been, however, small, have, devil, approximately,
# Nearest to if: dismissed, defaults, forgot, does, otherwise, neq, exist, vdash,
# Nearest to also: the, in, as, and, see, a, other, links,
# Nearest to who: reservations, maude, those, sheeana, to, duopoly, a, that,
# Nearest to smith: scrutinized, dongell, housekeeping, fouch, tardis, macneill, ubi, jackpot,
# Nearest to alternative: interplanetary, medicine, latinized, oclc, filled, steppe, sabian, synapsids,
# Nearest to instance: skilful, grrm, tacitus, plaintiff, federative, expository, rosemary, heterosexual,
# Nearest to recorded: buffalo, highwaymen, gaynor, recording, lukewarm, xander, erasing, hits,
# Nearest to experience: airplane, subconscious, forcing, ready, neurological, lens, innately, stamina,
# Nearest to rise: dimitris, reactant, rich, masturbation, caliphates, moralist, anabaptism, surfing,
# Nearest to dr: prof, niigata, encore, garp, valet, sextet, cruithne, yoruba,
# Nearest to cost: outperform, costs, constrained, earnings, sacrificing, rampton, maxims, menaced,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.7837 0.0582 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8180 0.0564 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8433 0.0559 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.7958 0.0561 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8264 0.0557 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8698 0.0590 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.7710 0.0554 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.7977 0.0558 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8537 0.0557 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8671 0.0571 sec/batch
# Nearest to time: had, reactivated, constantinopolitan, upon, costing, cabell, moment, now,
# Nearest to by: the, and, of, in, a, as, which, is,
# Nearest to in: the, of, and, a, as, to, with, first,
# Nearest to called: a, an, of, as, is, late, the, for,
# Nearest to were: had, been, was, the, became, have, in, however,
# Nearest to if: dismissed, does, we, neq, defaults, vdash, otherwise, forgetful,
# Nearest to also: the, in, as, see, and, is, a, other,
# Nearest to who: reservations, ligurian, those, gonzaga, nicomedia, duopoly, maude, working,
# Nearest to smith: scrutinized, dongell, fouch, housekeeping, tardis, reviewing, mcmaster, ubi,
# Nearest to alternative: interplanetary, latinized, medicine, filled, oclc, steppe, sabian, solicitor,
# Nearest to instance: grrm, skilful, plaintiff, tacitus, federative, rosemary, regarding, heterosexual,
# Nearest to recorded: buffalo, highwaymen, gaynor, erasing, rou, recording, nabawi, ulema,
# Nearest to experience: airplane, forcing, ready, subconscious, lens, sprung, neurological, innately,
# Nearest to rise: reactant, rich, dimitris, caliphates, masturbation, moralist, anabaptism, terraces,
# Nearest to dr: prof, niigata, encore, sextet, valet, cruithne, garp, yoruba,
# Nearest to cost: outperform, costs, sacrificing, earnings, constrained, preceded, vitrification, maxims,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8243 0.0579 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8014 0.0558 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8225 0.0557 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8166 0.0556 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.8704 0.0564 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.7893 0.0612 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9433 0.0567 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.8885 0.0563 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.8657 0.0555 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.7690 0.0579 sec/batch
# Nearest to time: had, reactivated, costing, upon, cabell, moment, constantinopolitan, based,
# Nearest to by: the, and, of, a, in, as, which, is,
# Nearest to in: the, and, of, a, with, as, to, was,
# Nearest to called: a, an, as, of, for, is, the, late,
# Nearest to were: had, was, been, killed, small, as, devil, including,
# Nearest to if: does, we, neq, vdash, defaults, dismissed, logically, have,
# Nearest to also: as, the, in, see, and, other, a, for,
# Nearest to who: reservations, maude, duopoly, working, those, milarepa, nicomedia, gonzaga,
# Nearest to smith: scrutinized, fouch, dongell, housekeeping, tardis, ubi, reviewing, mcmaster,
# Nearest to alternative: interplanetary, latinized, filled, bwv, medicine, oclc, steppe, sabian,
# Nearest to instance: grrm, skilful, tacitus, plaintiff, federative, expository, rosemary, regarding,
# Nearest to recorded: highwaymen, buffalo, erasing, rou, lukewarm, xander, ulema, gaynor,
# Nearest to experience: airplane, ready, forcing, subconscious, sprung, albury, cabins, lens,
# Nearest to rise: rich, dimitris, reactant, caliphates, masturbation, moralist, amur, terraces,
# Nearest to dr: prof, niigata, encore, sextet, cruithne, garp, syracuse, valet,
# Nearest to cost: outperform, costs, preceded, sacrificing, rampton, menaced, vitrification, donating,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.7944 0.0581 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.7788 0.0560 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.8063 0.0556 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8463 0.0556 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8047 0.0555 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8491 0.0560 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.8276 0.0470 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8141 0.0556 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.7868 0.0556 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8311 0.0565 sec/batch
# Nearest to time: had, upon, reactivated, costing, based, constantinopolitan, now, cabell,
# Nearest to by: the, and, of, a, in, as, which, was,
# Nearest to in: the, and, a, of, with, to, as, also,
# Nearest to called: a, as, of, an, late, the, also, for,
# Nearest to were: had, been, however, was, killed, as, devil, and,
# Nearest to if: dismissed, neq, exist, does, extra, logically, we, apocalypticism,
# Nearest to also: as, in, the, see, a, other, and, is,
# Nearest to who: ligurian, reservations, duopoly, working, quince, to, nicomedia, tutelary,
# Nearest to smith: scrutinized, fouch, housekeeping, dongell, tardis, ubi, macneill, mcmaster,
# Nearest to alternative: medicine, interplanetary, latinized, oclc, bwv, solicitor, sabian, downers,
# Nearest to instance: grrm, skilful, tacitus, plaintiff, federative, rosemary, markkaa, regarding,
# Nearest to recorded: highwaymen, xander, buffalo, erasing, ulema, rou, recording, lyrics,
# Nearest to experience: airplane, ready, subconscious, forcing, innately, cabins, neurological, sprung,
# Nearest to rise: rich, dimitris, reactant, caliphates, masturbation, moralist, surfing, resistant,
# Nearest to dr: prof, niigata, valet, encore, sextet, cruithne, syracuse, garp,
# Nearest to cost: outperform, costs, rampton, vitrification, preceded, earnings, taggers, menaced,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.7384 0.0566 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.7705 0.0555 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.7240 0.0551 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.8298 0.0546 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8006 0.0577 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8162 0.0565 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.7945 0.0573 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7015 0.0607 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.7457 0.0555 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.7185 0.0562 sec/batch
# Nearest to time: had, reactivated, upon, constantinopolitan, i, moment, now, cabell,
# Nearest to by: and, the, of, a, in, is, as, which,
# Nearest to in: the, and, a, of, with, as, to, also,
# Nearest to called: a, is, as, of, an, the, in, also,
# Nearest to were: had, was, been, however, killed, with, became, as,
# Nearest to if: we, dismissed, extra, neq, does, exist, defaults, vdash,
# Nearest to also: as, the, in, and, a, see, other, is,
# Nearest to who: reservations, ligurian, duopoly, those, working, tutelary, organisms, they,
# Nearest to smith: scrutinized, fouch, dongell, ubi, housekeeping, tardis, mcmaster, reviewing,
# Nearest to alternative: medicine, interplanetary, latinized, oclc, solicitor, sabian, steppe, bwv,
# Nearest to instance: grrm, skilful, tacitus, plaintiff, rosemary, federative, coloane, markkaa,
# Nearest to recorded: highwaymen, rou, erasing, xander, buffalo, recording, omitting, lyrics,
# Nearest to experience: airplane, subconscious, forcing, ready, pedagogic, sprung, neurological, stamina,
# Nearest to rise: dimitris, rich, reactant, caliphates, masturbation, moralist, surfing, converting,
# Nearest to dr: prof, niigata, valet, cruithne, encore, populous, garp, syracuse,
# Nearest to cost: outperform, costs, preceded, rampton, vitrification, earnings, taggers, menaced,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7630 0.0568 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.8166 0.0567 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8054 0.0599 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.7655 0.0617 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.8269 0.0561 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.8688 0.0606 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.7624 0.0644 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.8046 0.0562 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.8127 0.0562 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.7690 0.0659 sec/batch
# Nearest to time: had, upon, reactivated, constantinopolitan, moment, now, cabell, costing,
# Nearest to by: the, and, of, a, in, as, which, is,
# Nearest to in: the, a, and, of, with, as, to, also,
# Nearest to called: a, of, as, is, the, for, by, in,
# Nearest to were: had, been, was, however, have, karaite, became, could,
# Nearest to if: dismissed, defaults, extra, we, otherwise, neq, does, add,
# Nearest to also: as, the, in, and, see, other, a, is,
# Nearest to who: reservations, maude, those, working, ligurian, milarepa, ageless, oddparents,
# Nearest to smith: scrutinized, fouch, housekeeping, ubi, dongell, tardis, mcmaster, reviewing,
# Nearest to alternative: medicine, interplanetary, latinized, oclc, filled, solicitor, sabian, steppe,
# Nearest to instance: grrm, tacitus, plaintiff, skilful, coloane, rosemary, regarding, federative,
# Nearest to recorded: highwaymen, recording, lukewarm, rou, xander, erasing, buffalo, hoagie,
# Nearest to experience: airplane, neurological, forcing, subconscious, stamina, sprung, pedagogic, ready,
# Nearest to rise: dimitris, rich, reactant, masturbation, moralist, caliphates, bastards, resistant,
# Nearest to dr: prof, encore, niigata, valet, sextet, cruithne, garp, populous,
# Nearest to cost: costs, outperform, vitrification, preceded, rampton, earnings, batting, sacrificing,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.7931 0.0658 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8402 0.0573 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.8034 0.0568 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.7696 0.0556 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8199 0.0584 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8024 0.0559 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8154 0.0568 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.7789 0.0581 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.8085 0.0573 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.7860 0.0545 sec/batch
# Nearest to time: had, upon, reactivated, constantinopolitan, moment, now, costing, based,
# Nearest to by: the, and, of, a, in, as, is, which,
# Nearest to in: the, and, of, a, as, to, with, by,
# Nearest to called: a, is, as, by, of, the, in, an,
# Nearest to were: had, was, been, as, however, could, became, have,
# Nearest to if: we, dismissed, defaults, neq, does, extra, otherwise, allow,
# Nearest to also: the, as, and, in, a, see, other, is,
# Nearest to who: reservations, those, ligurian, they, that, a, working, to,
# Nearest to smith: scrutinized, fouch, housekeeping, dongell, ubi, tardis, mcmaster, reviewing,
# Nearest to alternative: medicine, latinized, interplanetary, filled, solicitor, sabian, imperatives, be,
# Nearest to instance: grrm, tacitus, skilful, federative, plaintiff, coloane, rosemary, regarding,
# Nearest to recorded: recording, rou, omitting, xander, erasing, highwaymen, buffalo, lyrics,
# Nearest to experience: airplane, forcing, subconscious, stamina, sprung, neurological, ready, cabins,
# Nearest to rise: dimitris, rich, reactant, masturbation, caliphates, nineteenth, resistant, badlands,
# Nearest to dr: prof, cruithne, niigata, encore, valet, sextet, populous, heresiologists,
# Nearest to cost: costs, outperform, preceded, vitrification, rampton, taggers, crts, batting,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8542 0.0575 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.7846 0.0552 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.8940 0.0554 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.8441 0.0552 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.8688 0.1795 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.7498 0.0815 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.7358 0.0550 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8249 0.0660 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7337 0.0554 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8194 0.0554 sec/batch
# Nearest to time: had, upon, moment, reactivated, costing, cabell, constantinopolitan, utc,
# Nearest to by: the, and, of, a, in, as, is, which,
# Nearest to in: the, and, of, with, a, to, as, also,
# Nearest to called: a, is, of, the, as, by, late, for,
# Nearest to were: had, was, been, killed, as, however, devil, became,
# Nearest to if: we, neq, dismissed, defaults, does, let, extra, forgot,
# Nearest to also: as, in, the, and, see, other, a, of,
# Nearest to who: working, reservations, ligurian, milarepa, oddparents, those, ucs, their,
# Nearest to smith: fouch, housekeeping, scrutinized, dongell, ubi, tardis, macneill, mcmaster,
# Nearest to alternative: latinized, bwv, medicine, interplanetary, filled, sabian, solicitor, imperatives,
# Nearest to instance: grrm, tacitus, skilful, coloane, plaintiff, rosemary, federative, markkaa,
# Nearest to recorded: recording, highwaymen, xander, lukewarm, lyrics, rou, hoagie, gaynor,
# Nearest to experience: airplane, forcing, subconscious, ready, sprung, stamina, cabins, malley,
# Nearest to rise: rich, dimitris, reactant, masturbation, caliphates, badlands, nineteenth, bastards,
# Nearest to dr: prof, encore, cruithne, populous, valet, niigata, sextet, garp,
# Nearest to cost: costs, outperform, earnings, rampton, vitrification, preceded, batting, crts,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8113 0.0582 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.8133 0.0552 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints\text8.ckpt

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
